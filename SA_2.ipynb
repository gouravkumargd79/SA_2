# %% [markdown]
# <a href="https://colab.research.google.com/github/gouravkumargd79/SA_2/blob/main/SA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?

'''The z-statistic is a measure that describes how many standard deviations a data point is away from the population mean. The formula for calculating the z-statistic is:

𝑧=𝑋−𝜇𝜎
z= σX−μ
​
Where:

𝑋
X is the sample value,
𝜇
μ is the population mean,
𝜎
σ is the population standard deviation.
The z-statistic follows the standard normal distribution, which is a normal distribution with a mean of 0 and a standard deviation of 1. In hypothesis testing, the z-statistic is used to determine how extreme a sample statistic is compared to a null hypothesis. A large positive or negative z-score indicates that the sample statistic is far from the null hypothesis value.'''

# Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?

'''A p-value is the probability of obtaining a test statistic (like the z-statistic) at least as extreme as the one observed, under the assumption that the null hypothesis is true. The p-value helps to determine the statistical significance of a result.

Small p-value (e.g., 0.01): This indicates strong evidence against the null hypothesis. A p-value of 0.01 means there is only a 1% chance of obtaining a result as extreme as the observed one if the null hypothesis were true. This is typically considered statistically significant, and we reject the null hypothesis.
Large p-value: Suggests weak evidence against the null hypothesis, meaning we fail to reject it.'''

# Question3: Compare and contrast the binomial and Bernoulli distributions.

'''Bernoulli Distribution: This is a discrete probability distribution of a random variable which has exactly two outcomes (success or failure). It is parameterized by a single probability
𝑝
p (probability of success), where
𝑝
p ranges from 0 to 1.

Example: Flipping a coin (success: heads, failure: tails).
Binomial Distribution: This is a generalization of the Bernoulli distribution. It models the number of successes in a fixed number of independent Bernoulli trials. It has two parameters:

𝑛
n: the number of trials

𝑝
p: the probability of success in each trial

Example: Tossing a coin 10 times and counting how many heads appear.'''

# Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli # distribution?

'''Binomial Distribution is used when:

There are a fixed number of trials (
𝑛
n).
Each trial is independent.
There are two possible outcomes (success or failure).
The probability of success
𝑝
p remains constant across trials.
The Bernoulli Distribution is a special case of the binomial distribution where
𝑛
=
1
n=1. Each Bernoulli trial is essentially a binomial trial with only one observation.'''

# Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?

'''Poisson Distribution is used to model the number of occurrences of an event within a fixed interval of time or space, where:
Events occur independently of one another.
The average rate (mean) of occurrence is constant over time or space.
Key Properties:
It is discrete.
It is defined by the parameter
𝜆
λ, which is the expected number of occurrences in the interval.
The Poisson distribution is often used in situations like:
The number of emails received in an hour.
The number of accidents occurring at a traffic intersection in a day.'''

# Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)?

'''Probability Distribution: It is a function that provides the probabilities of different possible outcomes in an experiment. It can be either discrete (probability mass function, PMF) or continuous (probability density function, PDF).

Probability Density Function (PDF): This is used to describe the probability distribution of a continuous random variable. The PDF gives the relative likelihood of a random variable taking a particular value. The area under the PDF curve over an interval gives the probability that the variable falls within that interval.

PMF (Probability Mass Function) is used for discrete random variables. It assigns probabilities to each possible outcome (e.g., a binomial distribution).'''

# Question7: Explain the Central Limit Theorem (CLT) with example.

'''The Central Limit Theorem states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the original distribution of the population. This holds when the samples are independent and identically distributed.

Example: If you repeatedly draw samples of size 30 from a population with a skewed distribution, the distribution of the sample means will approach a normal distribution as the number of samples increases.'''

# Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?

'''Z-scores: Used when the population standard deviation is known, and the sample size is large (typically
𝑛≥30
n≥30).

T-scores: Used when the population standard deviation is unknown and/or the sample size is small (
𝑛<30
n<30). The t-distribution accounts for the additional variability due to the estimation of the population standard deviation.'''

# Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis?

# Task: Write Python code to calculate the z-score and p-value for the given data.

# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.

'''Given:

Sample mean = 105
Population mean = 100
Standard deviation = 15
Sample size = 25
Significance level = 0.05
Z-score Formula:

𝑧=𝑋sample−𝜇𝜎/𝑛
z= σ/ n
​

Xsample−μ
​

P-value: Using the z-score, the p-value can be found from the standard normal distribution.

We will calculate the z-score and p-value using Python.'''

# Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?

# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.

# Objective: Understand the properties of a binomial distribution and verify them through simulation.

'''We need to simulate a binomial distribution with:

Number of trials = 10
Probability of success = 0.6
1,000 samples
We will generate the data, plot the distribution, and calculate the mean and variance.

Let me now provide Python code to calculate the z-score, p-value, and simulate the binomial distribution.

It seems like I can’t do more advanced data analysis right now. Please try again later. Let me know if you need assistance with anything else! ​'''
